# %% [markdown]
# <a href="https://colab.research.google.com/github/kh9yaz/124Rus/blob/master/ITOI_lab_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ФИО
#
# группа

# %% [markdown]
# Лабораторная работа 2
#
# Типы данных, основы визуализации данных

# %% [markdown]
# # Импорт данных, форматы

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %% [markdown]
# импорт БД задачи "ирисы Фишира" из пакета seaborn

# %%
data_iris = sns.load_dataset('iris')

display(data_iris.head(3))
display(data_iris.tail(3))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# Проверка форматов и наличия пропусков в данных

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Задание:**
#
# опишите в текстовой ячейке ниже, какие форматы данных у признаков (типы данных), есть ли пропуски и в каких столбцах?

# %% [markdown]
# 4 столбца (sepal_length, sepal_width, petal_length, petal_width) имеют тип данных float64
# Столбец species имеет тип данных object
#
#
# Пропусков нет

# %% [markdown]
# **Задание:**
#
# создайте списки числовых и категориальных признаков набора данных (указать имена столбцов ( ['name1', 'name2', ...] )

# %%
# Числовые признаки
numeric_features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# Категориальные признаки
categorical_features = ['species']

# %% [markdown]
# Описательная статистика для числовых данных

# %%
numerical_variables = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
numeric_stats = data_iris[numerical_variables].describe()
display(numeric_stats)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Описательная статистика для категориальных данных

# %%
categorical_variables = ['species']
categorical_stats = data_iris[categorical_variables].describe()
display(categorical_stats)
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %% [markdown]
# # Визуализация разброса и распределений данных

# %% [markdown]
# ## числовые данные

# %% [markdown]
# Пример для первой переменной "sepal_length"

# %%
sns.boxplot(data = data_iris, x = numerical_variables[0])
plt.show()

# %% [markdown]
# Группировка данных по классам (группам) из другой переменной. В задаче с ирисами - это естественная групировка по сортам ирисов.

# %%
sns.boxplot(data = data_iris, x = numerical_variables[0], y = 'species')
plt.show()

# %% [markdown]
# **Задание:**
#
# Постройте диаграммы boxplot для остальных числовых переменных как в примере выше.

# %%
numerical_variables = ['sepal_width', 'petal_length', 'petal_width']


plt.figure(figsize=(15, 10))

for i, variable in enumerate(numerical_variables, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(data=data_iris, x=variable, y='species', palette='Set2')
    plt.title(f'Boxplot of {variable} by Species')
    plt.xlabel(variable)
    plt.ylabel('Species')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-89e8eacf0d27>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data_iris, x=variable, y='species', palette='Set2')
# <ipython-input-20-89e8eacf0d27>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data_iris, x=variable, y='species', palette='Set2')
# <ipython-input-20-89e8eacf0d27>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data_iris, x=variable, y='species', palette='Set2')

# %% [markdown]
# ## категориальные данные

# %% [markdown]
# посчитать сколько раз встречается какая из категорий

# %%
data_iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
data_iris['species'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## гистограммы

# %% [markdown]
# Пример для первой переменной "sepal_length"

# %%
sns.histplot(data = data_iris, x = numerical_variables[0], stat = 'probability')
plt.show()

# %% [markdown]
# Тоже самое с оценкой плотности распределения

# %%
sns.histplot(data = data_iris, x = numerical_variables[0], stat = 'probability', kde = True)
plt.show()

# %% [markdown]
# Разбивка по группам

# %%
sns.histplot(data = data_iris, x = numerical_variables[0], stat = 'probability', kde = True, hue = 'species')
plt.show()

# %% [markdown]
# **Задание:**
#
# Постройте гистограмммы для остальных числовых переменных как в примере выше.

# %%
numerical_variables = ['sepal_width', 'petal_length', 'petal_width']


plt.figure(figsize=(15, 10))

for i, variable in enumerate(numerical_variables, 1):
    plt.subplot(2, 2, i)
    sns.histplot(data=data_iris, x=variable, stat='probability', kde=True, hue='species', palette='Set2')
    plt.title(f'Histogram of {variable} by Species')
    plt.xlabel(variable)
    plt.ylabel('Probability')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## парные графики переменных

# %%
sns.pairplot(data = data_iris)
plt.show()

# %% [markdown]
# **Задание**:
#
# Постройте аналогичный график с разбивкой по группам (параметр hue).

# %%
sns.pairplot(data=data_iris, hue='species', palette='Set2')
plt.show()
